# %%
 pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lazypredict in /home/onachi/.local/lib/python3.10/site-packages (0.2.12)
# Requirement already satisfied: tqdm in /home/onachi/.local/lib/python3.10/site-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from lazypredict) (8.0.3)
# Requirement already satisfied: scikit-learn in /home/onachi/.local/lib/python3.10/site-packages (from lazypredict) (1.1.3)
# Requirement already satisfied: lightgbm in /home/onachi/.local/lib/python3.10/site-packages (from lazypredict) (3.3.3)
# Requirement already satisfied: xgboost in /home/onachi/.local/lib/python3.10/site-packages (from lazypredict) (1.7.1)
# Requirement already satisfied: pandas in /home/onachi/.local/lib/python3.10/site-packages (from lazypredict) (1.5.1)
# Requirement already satisfied: joblib in /home/onachi/.local/lib/python3.10/site-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: scipy in /home/onachi/.local/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.9.3)
# Requirement already satisfied: numpy in /home/onachi/.local/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.23.4)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from lightgbm->lazypredict) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/onachi/.local/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->lazypredict) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/onachi/.local/lib/python3.10/site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv('p53_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
X.shape
# Out:
# (23, 881)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (23, 163)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|███████████████████████████████████████████| 42/42 [00:04<00:00,  9.57it/s]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|███████████████████████████████████████████| 42/42 [00:02<00:00, 17.91it/s]

# %% [markdown]
# # ERROR

# %%
predictions_train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# KernelRidge                                 22.23    -181.29  5.28        0.06
# QuantileRegressor                            1.12      -0.00  0.39        0.06
# LGBMRegressor                                1.12      -0.00  0.39        0.17
# HistGradientBoostingRegressor                1.12       0.00  0.39        0.07
# Lasso                                        1.12       0.00  0.39        0.01
# LassoLars                                    1.12       0.00  0.39        0.05
# ElasticNet                                   1.12       0.00  0.39        0.04
# DummyRegressor                               1.12       0.00  0.39        0.04
# LassoLarsCV                                  1.08       0.35  0.32        0.09
# LarsCV                                       1.08       0.35  0.32        0.10
# KNeighborsRegressor                          1.06       0.48  0.28        0.12
# BayesianRidge                                1.06       0.51  0.27        0.17
# OrthogonalMatchingPursuitCV                  1.04       0.64  0.23        0.01
# SVR                                          1.03       0.75  0.20        0.01
# Lars                                         1.03       0.75  0.19        0.04
# LassoCV                                      1.03       0.75  0.19        0.17
# ElasticNetCV                                 1.03       0.76  0.19        0.46
# NuSVR                                        1.03       0.79  0.18        0.01
# LinearSVR                                    1.02       0.80  0.17        0.04
# GammaRegressor                               1.02       0.82  0.16        1.02
# TweedieRegressor                             1.02       0.82  0.16        0.12
# BaggingRegressor                             1.02       0.84  0.16        0.02
# SGDRegressor                                 1.02       0.86  0.15        0.01
# RandomForestRegressor                        1.02       0.86  0.14        0.13
# RidgeCV                                      1.01       0.88  0.14        0.03
# PassiveAggressiveRegressor                   1.01       0.90  0.13        0.02
# PoissonRegressor                             1.01       0.93  0.10        0.11
# HuberRegressor                               1.01       0.93  0.10        0.04
# Ridge                                        1.01       0.95  0.09        0.01
# LinearRegression                             1.01       0.95  0.09        0.06
# TransformedTargetRegressor                   1.01       0.95  0.09        0.01
# OrthogonalMatchingPursuit                    1.01       0.95  0.09        0.02
# AdaBoostRegressor                            1.00       0.98  0.06        0.08
# MLPRegressor                                 1.00       0.98  0.05        0.17
# GradientBoostingRegressor                    1.00       1.00  0.00        0.08
# XGBRegressor                                 1.00       1.00  0.00        0.41
# GaussianProcessRegressor                     1.00       1.00  0.00        0.03
# ExtraTreesRegressor                          1.00       1.00  0.00        0.10
# ExtraTreeRegressor                           1.00       1.00  0.00        0.01
# DecisionTreeRegressor                        1.00       1.00  0.00        0.05

# %%
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# KernelRidge                                  3.43     -95.70  5.78        0.02
# GaussianProcessRegressor                     3.23     -87.61  5.54        0.02
# MLPRegressor                                 1.21      -7.41  1.71        0.20
# OrthogonalMatchingPursuit                    1.08      -2.25  1.06        0.01
# AdaBoostRegressor                            1.06      -1.21  0.87        0.09
# ExtraTreeRegressor                           1.05      -1.07  0.85        0.02
# XGBRegressor                                 1.05      -0.99  0.83        0.09
# OrthogonalMatchingPursuitCV                  1.05      -0.88  0.81        0.02
# SGDRegressor                                 1.04      -0.75  0.78        0.02
# ElasticNetCV                                 1.04      -0.74  0.78        0.31
# LassoCV                                      1.04      -0.74  0.78        0.17
# GradientBoostingRegressor                    1.04      -0.72  0.77        0.08
# LinearSVR                                    1.04      -0.71  0.77        0.01
# ExtraTreesRegressor                          1.04      -0.69  0.76        0.10
# DecisionTreeRegressor                        1.04      -0.65  0.76        0.01
# BaggingRegressor                             1.04      -0.65  0.75        0.03
# RandomForestRegressor                        1.04      -0.51  0.72        0.11
# GammaRegressor                               1.04      -0.50  0.72        0.02
# TweedieRegressor                             1.04      -0.48  0.72        0.04
# HuberRegressor                               1.04      -0.47  0.71        0.04
# TransformedTargetRegressor                   1.04      -0.45  0.71        0.01
# LinearRegression                             1.04      -0.45  0.71        0.01
# RidgeCV                                      1.04      -0.45  0.71        0.02
# Ridge                                        1.04      -0.43  0.70        0.01
# PoissonRegressor                             1.04      -0.43  0.70        0.02
# SVR                                          1.04      -0.42  0.70        0.03
# KNeighborsRegressor                          1.04      -0.40  0.70        0.01
# BayesianRidge                                1.03      -0.39  0.69        0.02
# PassiveAggressiveRegressor                   1.03      -0.39  0.69        0.02
# NuSVR                                        1.03      -0.39  0.69        0.02
# Lars                                         1.03      -0.37  0.69        0.04
# LassoLarsCV                                  1.03      -0.28  0.67        0.06
# LarsCV                                       1.03      -0.28  0.67        0.09
# QuantileRegressor                            1.03      -0.20  0.64        0.02
# LGBMRegressor                                1.03      -0.16  0.63        0.34
# Lasso                                        1.03      -0.16  0.63        0.01
# HistGradientBoostingRegressor                1.03      -0.16  0.63        0.07
# ElasticNet                                   1.03      -0.16  0.63        0.01
# DummyRegressor                               1.03      -0.16  0.63        0.02
# LassoLars                                    1.03      -0.16  0.63        0.01

# %% [markdown]
# # ERORR

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.8
